# %% [markdown]
# # Scraping Data From a Real Website + Pandas 2

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://companiesmarketcap.com/inr/'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-IN">
# <head>
# <title>Companies ranked by Market Cap - CompaniesMarketCap.com</title>
# <meta charset="utf-8"/>
# <link href="https://companiesmarketcap.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/img/icons/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/img/icons/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/img/icons/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/img/icons/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/img/icons/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/img/icons/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/img/icons/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/img/icons/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# ...

# %%
soup.find_all('table')
# Out:
# [<table class="default-table table marketcap-table dataTable" style="width:100%">
#  <thead><tr><th class="th-id-1" tid="1"></th><th class="th-id-2 th-rank sorting sorting_asc" tid="2">Rank</th><th class="th-id-3 th-name sorting" tid="3">Name<div class="afterElem"></div></th><th class="th-id-4 th-mcap sorting text-right" tid="4">Market Cap</th><th class="th-id-5 th-price sorting text-right" tid="5">Price</th><th class="th-id-6 th-1d sorting rh-sm" tid="6">Today</th><th class="th-id-7 th-30d no-sort" tid="7">Price (30 days)</th><th class="th-id-8 th-country sorting" tid="8">Country</th></tr></thead> <tbody>
# ...

# %%
soup.find('table', class_ ='default-table table marketcap-table dataTable' )
# Out:
# <table class="default-table table marketcap-table dataTable" style="width:100%">
# <thead><tr><th class="th-id-1" tid="1"></th><th class="th-id-2 th-rank sorting sorting_asc" tid="2">Rank</th><th class="th-id-3 th-name sorting" tid="3">Name<div class="afterElem"></div></th><th class="th-id-4 th-mcap sorting text-right" tid="4">Market Cap</th><th class="th-id-5 th-price sorting text-right" tid="5">Price</th><th class="th-id-6 th-1d sorting rh-sm" tid="6">Today</th><th class="th-id-7 th-30d no-sort" tid="7">Price (30 days)</th><th class="th-id-8 th-country sorting" tid="8">Country</th></tr></thead> <tbody>
# ...

# %%
table = soup.find('table', class_ ='default-table table marketcap-table dataTable' )

# %%
table
# Out:
# <table class="default-table table marketcap-table dataTable" style="width:100%">
# <thead><tr><th class="th-id-1" tid="1"></th><th class="th-id-2 th-rank sorting sorting_asc" tid="2">Rank</th><th class="th-id-3 th-name sorting" tid="3">Name<div class="afterElem"></div></th><th class="th-id-4 th-mcap sorting text-right" tid="4">Market Cap</th><th class="th-id-5 th-price sorting text-right" tid="5">Price</th><th class="th-id-6 th-1d sorting rh-sm" tid="6">Today</th><th class="th-id-7 th-30d no-sort" tid="7">Price (30 days)</th><th class="th-id-8 th-country sorting" tid="8">Country</th></tr></thead> <tbody>
# ...

# %%
titles = table.find_all('th')

# %%
titles
# Out:
# [<th class="th-id-1" tid="1"></th>,
#  <th class="th-id-2 th-rank sorting sorting_asc" tid="2">Rank</th>,
#  <th class="th-id-3 th-name sorting" tid="3">Name<div class="afterElem"></div></th>,
#  <th class="th-id-4 th-mcap sorting text-right" tid="4">Market Cap</th>,
#  <th class="th-id-5 th-price sorting text-right" tid="5">Price</th>,
#  <th class="th-id-6 th-1d sorting rh-sm" tid="6">Today</th>,
#  <th class="th-id-7 th-30d no-sort" tid="7">Price (30 days)</th>,
#  <th class="th-id-8 th-country sorting" tid="8">Country</th>]

# %%
table_titles = [title.text.strip() for title in titles[1:]]

print(table_titles)
# Out:
# ['Rank', 'Name', 'Market Cap', 'Price', 'Today', 'Price (30 days)', 'Country']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = table_titles)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Market Cap, Price, Today, Price (30 days), Country]
# Index: []

# %%
column_data = table.find_all('tr')

for row in column_data:
    row_data = row.find_all('td')
    
    # [1:] skips the first 'td' (the favorite column)
    individual_row_data = [data.text.strip() for data in row_data[1:]] 
    
    if len(individual_row_data) == len(df.columns):
        length = len(df)
        df.loc[length] = individual_row_data

# %%
df
# Out:
#    Rank                   Name  Market Cap    Price  Today Price (30 days)  \
# 0     1             NVIDIANVDA  ₹477.106 T  ₹19,698  2.34%
# 1     2              AppleAAPL  ₹445.823 T  ₹30,354  0.69%
# 2     3  Alphabet (Google)GOOG  ₹411.677 T  ₹33,737  0.61%
# 3     4          MicrosoftMSFT  ₹277.360 T  ₹37,338  1.41%
# 4     5             AmazonAMZN  ₹254.828 T  ₹23,689  0.99%
# ..  ...                    ...         ...      ...    ...             ...
# 95   96           SantanderSAN   ₹18.692 T   ₹1,306  1.55%
# 96   97          InditexITX.MC   ₹18.619 T   ₹5,980  0.29%
# 97   98            AmphenolAPH   ₹18.522 T  ₹15,056  1.00%
# 98   99            McDonaldMCD   ₹18.460 T  ₹25,982  1.04%
# 99  100              AmgenAMGN   ₹18.411 T  ₹34,115  1.81%
#
#      Country
# 0     🇺🇸 USA
# 1     🇺🇸 USA
# 2     🇺🇸 USA
# 3     🇺🇸 USA
# 4     🇺🇸 USA
# ..       ...
# 95  🇪🇸 Spain
# 96  🇪🇸 Spain
# 97    🇺🇸 USA
# 98    🇺🇸 USA
# 99    🇺🇸 USA
#
# [100 rows x 7 columns]

# %%
df.to_csv(r'C:\Users\omkar\OneDrive\Desktop\Data Analyst\Python\Demo\csv files\topcomp.csv', index = False)
