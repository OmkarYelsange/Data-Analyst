# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
pd.read_csv(r"C:\Users\omkar\OneDrive\Desktop\Data Analyst\Python\Demo\csv files\Sales.csv")
# Out:
#            Country      Australia     Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 0              NaN            NaN            NaN             NaN         NaN
# 1       Row Labels  Sum of Profit    Sum of Cost  Sum of Revenue         NaN
# 2  New South Wales    ? 31,33,684    ? 60,69,811          43.20%         NaN
# 3       Queensland    ? 16,19,158    ? 34,47,109          23.78%         NaN
# 4  South Australia     ? 4,24,839     ? 9,72,435           6.56%         NaN
# 5         Tasmania     ? 1,70,323     ? 4,09,861           2.72%         NaN
# 6         Victoria    ? 14,28,026    ? 36,26,813          23.73%         NaN
# 7      Grand Total    ? 67,76,030  ? 1,45,26,029         100.00%         NaN
# 8              NaN            NaN            NaN             NaN         NaN
# 9              NaN            NaN            NaN             NaN         NaN
#
#    Unnamed: 5  Unnamed: 6      Unnamed: 7     Unnamed: 8   Unnamed: 9  \
# ...
